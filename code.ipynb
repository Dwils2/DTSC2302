# %%
import pandas as pd

data = pd.read_csv('/workspaces/DTSC2302/421-a_16__Affordable_New_York_Housing_Program_Completion_Extension_-_Letters_of_Intent_20250422.csv')

# %%
data
# Out:
#      No. FORM SUBMISSION DATE                    REPORTED PROPERTY ADDRESSES  \
# 0      1           06/14/2024           155 Third Street, Brooklyn, NY 11231
# 1      2           06/14/2024            267 Bond Street, Brooklyn, NY 11217
# 2      3           06/14/2024                498 Sackett Street Brooklyn, NY
# 3      4           06/17/2024                          247 East 117th Street
# 4      5           06/17/2024            240 4th Avenue, Brooklyn, NY, 11215
# ..   ...                  ...                                            ...
# 735  736           09/12/2024                             250 East 83 Street
# 736  737           09/12/2024  44-14 Douglaston Parkway, Douglaston NY 11363
# 737  738           09/12/2024      2721 Colden Avenue, Bronx, New York 10469
# 738  739           09/12/2024                                  100 Union Ave
# 739  740           09/12/2024                           1777 Nostrand Avenue
#
# ...

# %%
data.isnull().sum()
# Out:
# No.                                            0
# FORM SUBMISSION DATE                           0
# REPORTED PROPERTY ADDRESSES                    0
# REPORTED BOROUGH                               0
# REPORTED DOB BIN NUMBER                        0
# REPORTED DOB PERMIT SEQUENCE                   0
# REPORTED UNITS                                 0
# REPORTED AFFORDALE UNITS                       0
# REPORTED COMMENCEMENT DATE                     0
# REPORTED ANTICIPATED COMPLETION DATE           0
# REPORTED PROPERTY TAX BLOCK                    0
# REPORTED PROPERTY TAX LOT(S)                   0
# REPORTED AFFORDABILITY OPTION                  0
# PRESUMED BOROUGH                               0
# PRESUMED COMMUNITY BOARD                       0
# PRESUMED COUNCIL DISTRICT                      0
# PRESUMED DUPLICATE                           597
# PRESUMED DUPLICATE WEIGHT                      0
# PRESUMED BUILDING UNITS                        0
# ...

# %%
data = data.dropna(subset=['REPORTED AFFORDALE UNITS', 'PRESUMED BUILDING AFFORDABLE UNITS'])

# %%
column_names = data.columns
print(column_names)
# Out:
# Index(['No.', 'FORM SUBMISSION DATE', 'REPORTED PROPERTY ADDRESSES',
#        'REPORTED BOROUGH', 'REPORTED DOB BIN NUMBER',
#        'REPORTED DOB PERMIT SEQUENCE', 'REPORTED UNITS',
#        'REPORTED AFFORDALE UNITS', 'REPORTED COMMENCEMENT DATE',
#        'REPORTED ANTICIPATED COMPLETION DATE', 'REPORTED PROPERTY TAX BLOCK',
#        'REPORTED PROPERTY TAX LOT(S)', 'REPORTED AFFORDABILITY OPTION',
#        'PRESUMED BOROUGH', 'PRESUMED COMMUNITY BOARD',
#        'PRESUMED COUNCIL DISTRICT', 'PRESUMED DUPLICATE',
#        'PRESUMED DUPLICATE WEIGHT', 'PRESUMED BUILDING UNITS',
#        'PRESUMED BUILDING AFFORDABLE UNITS', 'PRESUMED LOT', 'POSTCODE',
#        'LATITUDE', 'LONGITUDE', 'BBL', 'CENSUS TRACT (2020)',
#        'NEIGHBORHOOD TABULATION AREA (NTA) (2020)'],
#       dtype='object')

# %%
print("Data types: ")
print(data.dtypes)
# Out:
# Data types:
# No.                                            int64
# FORM SUBMISSION DATE                          object
# REPORTED PROPERTY ADDRESSES                   object
# REPORTED BOROUGH                              object
# REPORTED DOB BIN NUMBER                       object
# REPORTED DOB PERMIT SEQUENCE                  object
# REPORTED UNITS                                 int64
# REPORTED AFFORDALE UNITS                       int64
# REPORTED COMMENCEMENT DATE                    object
# REPORTED ANTICIPATED COMPLETION DATE          object
# REPORTED PROPERTY TAX BLOCK                    int64
# REPORTED PROPERTY TAX LOT(S)                  object
# REPORTED AFFORDABILITY OPTION                 object
# PRESUMED BOROUGH                              object
# PRESUMED COMMUNITY BOARD                       int64
# PRESUMED COUNCIL DISTRICT                      int64
# PRESUMED DUPLICATE                            object
# ...
